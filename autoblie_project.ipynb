# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\punit\Downloads\automobile.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       199 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
df=df.drop_duplicates().reset_index(drop=True)
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       199 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    37
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df.drop(columns=['symboling'],inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  164 non-null    float64
#  1   make               201 non-null    object
#  2   fuel-type          201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       199 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %%
missing_door=df[df['num-of-doors'].isnull()]
print(missing_door)
# Out:
#     normalized-losses   make fuel-type aspiration num-of-doors body-style  \
# 26              148.0  dodge       gas      turbo          NaN      sedan
# 60                NaN  mazda    diesel        std          NaN      sedan
#
#    drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 26          fwd           front        93.7   157.3  ...           98
# 60          fwd           front        98.8   177.8  ...          122
#
#     fuel-system  bore stroke compression-ratio  horsepower peak-rpm  city-mpg  \
# 26         mpfi  3.03   3.39               7.6       102.0   5500.0        24
# 60          idi  3.39   3.39              22.7        64.0   4650.0        36
#
#     highway-mpg  price
# 26           30   8558
# 60           42  10795
#
# [2 rows x 25 columns]

# %%
df['num-of-doors']=df['num-of-doors'].fillna('four')

# %%
df.drop(columns=['fuel-type','normalized-losses','peak-rpm','bore','stroke','fuel-system','compression-ratio'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   make              201 non-null    object
#  1   aspiration        201 non-null    object
#  2   num-of-doors      201 non-null    object
#  3   body-style        201 non-null    object
#  4   drive-wheels      201 non-null    object
#  5   engine-location   201 non-null    object
#  6   wheel-base        201 non-null    float64
#  7   length            201 non-null    float64
#  8   width             201 non-null    float64
#  9   height            201 non-null    float64
#  10  curb-weight       201 non-null    int64
#  11  engine-type       201 non-null    object
#  12  num-of-cylinders  201 non-null    object
#  13  engine-size       201 non-null    int64
#  14  horsepower        199 non-null    float64
#  15  city-mpg          201 non-null    int64
# ...

# %%
#To check the distribution of cars across different body style

# %%
sns.countplot(data=df,y='body-style',color='gold')
plt.grid(linestyle=':')
plt.title('numers of cars per bodytype')
plt.title('Numbers of cars per body type')
# Out:
# Text(0.5, 1.0, 'Numbers of cars per body type')

# %%
#if we want to data in a high to low order
plt.Figure(figsize=(6,4))
sns.countplot(data=df,y='body-style',order=(df['body-style'].value_counts().index))
# Out:
# <Axes: xlabel='count', ylabel='body-style'>

# %%
#To check the distribution of cars acrcoss different body style with include doors numbers

# %%
plt.Figure(figsize=(6,4))
sns.countplot(data=df,y='body-style',hue='num-of-doors')
plt.title('Numbers of car per bodytype and door numbers',y=1.02)
# Out:
# Text(0.5, 1.02, 'Numbers of car per bodytype and door numbers')

# %%
# to check the average engine size in each bodystyle
plt.Figure(figsize=(6,4))
sns.barplot(data=df,x='engine-size',y='body-style',estimator='mean',errorbar=None)
plt.grid(linestyle=':')
plt.title('Average engine size in each bodystyle')
# Out:
# Text(0.5, 1.0, 'Average engine size in each bodystyle')

# %%
#how does the engine size vary across different body style splits over number of doors

# %%
#barplot
sns.barplot(data=df,x='engine-size',y='body-style',hue='num-of-doors',estimator='mean',errorbar=None)
plt.title('Average engine size vary across different body style splits over number of doors')
# Out:
# Text(0.5, 1.0, 'Average engine size vary across different body style splits over number of doors')

# %%
#catplot
barplot=sns.catplot(kind='bar',data=df,y='body-style',x='engine-size', col='num-of-doors',estimator='mean',errorbar=None)
barplot.set_axis_labels('Average engine size','Car bodystyle')
barplot.fig.suptitle('Average engine size vary across different body style splits over number of doors',y=1.08)
# Out:
# Text(0.5, 1.08, 'Average engine size vary across different body style splits over number of doors')

# %%
#by use of pivot table
pivot=df.pivot_table(index='body-style',columns='num-of-doors', values='engine-size',aggfunc='mean')
pivot.plot(kind='barh', stacked=False)
# Out:
# <Axes: ylabel='body-style'>

# %%
#what is the distribution of car price

# %%
sns.histplot(data=df,x='price',bins=10,color='linen')
plt.ylabel('number of cars')
plt.title('distribution of price' )
# Out:
# Text(0.5, 1.0, 'distribution of price')

# %%
#what is the distribution of price of cars split over bodystyle
sns.histplot(data=df,x='price',hue='body-style', bins=10,multiple='stack')
plt.ylabel('number of cars')
plt.title('distribution of price split over bodystyle')
# Out:
# Text(0.5, 1.0, 'distribution of price split over bodystyle')

# %%
# what is the distribution of city mileage of cars

# %%
df['city-mpg'].describe()
# Out:
# count    201.000000
# mean      25.179104
# std        6.423220
# min       13.000000
# 25%       19.000000
# 50%       24.000000
# 75%       30.000000
# max       49.000000
# Name: city-mpg, dtype: float64

# %%
# using histogram
sns.histplot(data=df,x='city-mpg',bins=10)
plt.axvline(19,c='r')
plt.axvline(24,c='r')
plt.axvline(30,c='r')
plt.title('distribution of city mileage of cars' )
# Out:
# Text(0.5, 1.0, 'distribution of city mileage of cars')

# %%
# using boxplot
sns.boxplot(data=df,x='city-mpg')
plt.title('distribution of city mileage of cars' )
# Out:
# Text(0.5, 1.0, 'distribution of city mileage of cars')

# %%
# distribution of city milege splits over car body style
sns.boxplot(data=df,x='city-mpg',y='body-style')
plt.title('distribution of city mileage splits over car body style')
# Out:
# Text(0.5, 1.0, 'distribution of city mileage splits over car body style')

# %%
sns.boxplot(data=df,x='city-mpg',y='body-style',hue='num-of-doors')
plt.title('distribution of city mileage splits over car body style and number of doors')
# Out:
# Text(0.5, 1.0, 'distribution of city mileage splits over car body style and number of doors')

# %%
# what is the distribution of horse power across the cars
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.histplot(data=df,x='horsepower')
plt.title('distribution of horse power',fontsize=12)
plt.xlabel('Horsepower',fontsize=12)
plt.ylabel('Frequency',fontsize=12)
plt.subplot(1,2,2)
sns.kdeplot(data=df,x='horsepower',fill=True)
plt.title('Distribution of horse power')
plt.xlabel('horsepower',fontsize=12)
plt.ylabel('Probabilty Density',fontsize=12)
# Out:
# Text(0, 0.5, 'Probabilty Density')

# %%
sns.histplot(data=df,x='horsepower',kde=True)
plt.title('distribution of horsepower')
# Out:
# Text(0.5, 1.0, 'distribution of horsepower')

# %%
#what is correlation between numerical columns
df_num=df[['curb-weight','horsepower','city-mpg','highway-mpg','price']]
corr=df_num.corr().round(2)

# %%
sns.heatmap(data=corr,annot=True,fmt='.2f',cmap='coolwarm',linewidths=0.5)
# Out:
# <Axes: >
